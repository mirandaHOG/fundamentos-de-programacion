# %% [markdown]
# <a href="https://colab.research.google.com/github/mirandaHOG/fundamentos-de-programacion/blob/main/programatriangulo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
base = int (input("dame la base del triangulo"))
altura = int (input("dame la altura del triangulo"))
area = (base * altura)/2
print("el area del triangulo es", area)
# Out:
# dame la base del triangulo10
# dame la altura del triangulo20
# el area del triangulo es 100.0

# %%
variable1 = 30
variable2 = 50
if variable1 > variable2:
    print(variable1,"es mayor que",variable2)
else:
    print(variable2,"es menor que",variable1)
# Out:
# 50 es menor que 30

# %%
variable1 = 70
variable2 = 70
if variable1 > variable2:
    print(variable1,"es mayor que",variable2)
elif variable1 == variable2:
    print(variable1,"es igual que",variable2)
else:
    print(variable2,"es menor que",variable1)
# Out:
# 70 es igual que 70
