# %% [markdown]
# <a href="https://colab.research.google.com/github/mirandaHOG/fundamentos-de-programacion/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=5
print("x es igual a:", x)
# Out:
# x es igual a: 5
